# %% [markdown]
# ## **Programa para la generación de ubicación en Mapa de direcciones de concesionarios de HINO en todo el pais**
#
# Se hace uso de la integración con Google Maps, el cual coconvierte las direcciones proporcionadas en cordenadas Latitud longitud dentro de un mapa en Google Maps

# %%
# !pip install geopy folium

# %% [markdown]
#  código para generar el mapa

# %%
from geopy.geocoders import GoogleV3
import folium

# Reemplaza 'YOUR_API_KEY' con tu clave API de Google Maps
geolocator = GoogleV3(api_key='AIzaSyCs9CH_C9oCmhQpJksJMlKa4vE1BpbuiIM')   # Poner aqui el API Key habilitado para integracion

concesionarios = [
    {"Concesionario": "Autoamérica – Medellín", "Ciudad": "Medellín", "Dirección": "Transversal 78 N° 65-346"},
    {"Concesionario": "Autonorte", "Ciudad": "Bogotá", "Dirección": "Av. Circunvalar Calle 110 No 43 C - 91"},
    {"Concesionario": "Carrazos – Tunja", "Ciudad": "Tunja", "Dirección": "Calle 53 N° 5-98"},
    {"Concesionario": "Praco Didacol Américas - Bogotá", "Ciudad": "Bogotá", "Dirección": "Av. de las Américas N° 39-63"},
    {"Concesionario": "Praco Didacol – Bucaramanga", "Ciudad": "Bucaramanga", "Dirección": "Calle 70 N° 32W-92 Km. 4, Vía Girón"},
    {"Concesionario": "Praco Didacol Calle 80 – Bogotá", "Ciudad": "Bogotá", "Dirección": "Autopista Medellín Km 1.2 Vía Siberia Costado Sur"},
    {"Concesionario": "Praco Didacol Itagüí – Medellín", "Ciudad": "Medellín", "Dirección": "Cra 42 N° 46-130"},
    {"Concesionario": "Praco Didacol – Pereira", "Ciudad": "Pereira", "Dirección": "Av. 30 de Agosto No. 33-09"},
    {"Concesionario": "Praco Didacol Yumbo - Cali", "Ciudad": "Cali", "Dirección": "Cra 36 No. 15 - 95 - Acopi-Yumbo"},
    {"Concesionario": "Motor Hino de Nariño", "Ciudad": "Pasto", "Dirección": "Carrera 41 No 18-31 Av. Panamericana"},
    {"Concesionario": "Motorsur Ibagué", "Ciudad": "Ibagué", "Dirección": "Carrera 48 sur No. 89 - 29"},
    {"Concesionario": "Motorsur Neiva", "Ciudad": "Neiva", "Dirección": "Carrera 5 # No. 11- 46 sur"},
    {"Concesionario": "Tulog Mantenimiento & Confiabilidad SAS", "Ciudad": "Barranquilla", "Dirección": "Carrera 1 Calle 18 - Bodega 15 Barrio Villa Nieves Anillo Vial"},
    {"Concesionario": "Vehidiesel", "Ciudad": "Cartagena", "Dirección": "Diagonal 21 Nº 45A 112"},
    {"Concesionario": "Vehicaldas - Manizales", "Ciudad": "Manizales", "Dirección": "Cra 31 # 98A-15 Lote la Matilde, vía al Magdalena sector Puente La L"},
    {"Concesionario": "Yokomotor Fontibón - Bogotá", "Ciudad": "Bogotá", "Dirección": "Diagonal 16 N° 96j-15"}
]

m = folium.Map(location=[4.5709, -74.2973], zoom_start=6)

for concesionario in concesionarios:
    location = geolocator.geocode(f"{concesionario['Dirección']}, {concesionario['Ciudad']}, Colombia")
    if location:
        folium.Marker(
            [location.latitude, location.longitude],
            popup=f"{concesionario['Concesionario']} - {concesionario['Ciudad']}",
            tooltip=concesionario['Concesionario']
        ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
m.save("concesionarios_hino_colombia.html")
